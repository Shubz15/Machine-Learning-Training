# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubz15/Machine-Learning-Training/blob/main/Exp_3/Experiment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("Student_Academic_Performance.csv")
print("Initial Dataset Shape:", df.shape)
print("\nFirst 5 Records of Dataset:\n")
print(df.head())
# Out:
# Initial Dataset Shape: (205, 10)
#
# First 5 Records of Dataset:
#
#    Student_ID  Gender  Study_Hours  Attendance_Percentage Parent_Education  \
# 0        1001    Male          3.6                   68.0       HighSchool
# 1        1002    Male          7.7                   96.0     Postgraduate
# 2        1003  Female          6.1                   55.0     Postgraduate
# 3        1004    Male          5.2                   93.0       HighSchool
# 4        1005    Male          2.1                   52.0       HighSchool
#
#    Internal_Assessment  Lab_Test_Score  External_POE_Score ESE_Preparation  \
# 0                 17.0              16                  17       Completed
# 1                 22.0              18                  13       Completed
# 2                 10.0              20                  17   Not Completed
# 3                 25.0              21                  18   Not Completed
# 4                 16.0              19                  12   Not Completed
#
#   Department
# 0        CSE
# 1       ENTC
# 2       ENTC
# 3       ENTC
# 4       ENTC

# %%
print("\nDataset Information:\n")
print(df.info())
print("\nSummary Statistics:\n")
print(df.describe())
# Out:
# Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             205 non-null    int64
#  1   Gender                 205 non-null    object
#  2   Study_Hours            199 non-null    float64
#  3   Attendance_Percentage  200 non-null    float64
#  4   Parent_Education       205 non-null    object
#  5   Internal_Assessment    200 non-null    float64
#  6   Lab_Test_Score         205 non-null    int64
#  7   External_POE_Score     205 non-null    int64
#  8   ESE_Preparation        205 non-null    object
#  9   Department             205 non-null    object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 16.1+ KB
# None
#
# Summary Statistics:
#
#         Student_ID  Study_Hours  Attendance_Percentage  Internal_Assessment  \
# count   205.000000   199.000000             200.000000           200.000000
# mean   1100.151220     4.388945              74.185000            19.630000
# std      57.855902     2.066906              15.636601             5.778412
# min    1001.000000     1.000000              45.000000            10.000000
# 25%    1050.000000     2.700000              62.750000            14.000000
# 50%    1100.000000     4.500000              75.000000            20.000000
# 75%    1150.000000     6.200000              88.250000            25.000000
# max    1200.000000     7.900000              99.000000            29.000000
#
#        Lab_Test_Score  External_POE_Score
# count      205.000000          205.000000
# mean        16.678049           17.078049
# std          4.482401            4.394042
# min         10.000000           10.000000
# 25%         13.000000           13.000000
# 50%         17.000000           17.000000
# 75%         21.000000           21.000000
# max         24.000000           24.000000

# %%
print("\nMissing Values Before Cleaning:\n")
print(df.isnull().sum())
# Out:
# Missing Values Before Cleaning:
#
# Student_ID               0
# Gender                   0
# Study_Hours              6
# Attendance_Percentage    5
# Parent_Education         0
# Internal_Assessment      5
# Lab_Test_Score           0
# External_POE_Score       0
# ESE_Preparation          0
# Department               0
# dtype: int64

# %%
df["Study_Hours"] = df["Study_Hours"].fillna(df["Study_Hours"].mean())
df["Attendance_Percentage"] =df["Attendance_Percentage"].fillna(df["Attendance_Percentage"].mean())
df["Internal_Assessment"] = df["Internal_Assessment"].fillna(df["Internal_Assessment"].mean())
print("\nMissing Values After Cleaning:\n")
print(df.isnull().sum())
# Out:
# Missing Values After Cleaning:
#
# Student_ID               0
# Gender                   0
# Study_Hours              0
# Attendance_Percentage    0
# Parent_Education         0
# Internal_Assessment      0
# Lab_Test_Score           0
# External_POE_Score       0
# ESE_Preparation          0
# Department               0
# dtype: int64

# %%
df["Study_Hours"] = df["Study_Hours"].fillna(df["Study_Hours"].mean())
df["Attendance_Percentage"] =df["Attendance_Percentage"].fillna(df["Attendance_Percentage"].mean())
df["Internal_Assessment"] = df["Internal_Assessment"].fillna(df["Internal_Assessment"].mean())
print("\nMissing Values After Cleaning:\n")
print(df.isnull().sum())
# Out:
# Missing Values After Cleaning:
#
# Student_ID               0
# Gender                   0
# Study_Hours              0
# Attendance_Percentage    0
# Parent_Education         0
# Internal_Assessment      0
# Lab_Test_Score           0
# External_POE_Score       0
# ESE_Preparation          0
# Department               0
# dtype: int64

# %%
print("\nDataset Shape Before Removing Duplicates:", df.shape)
df = df.drop_duplicates()
print("Dataset Shape After Removing Duplicates:", df.shape)
# Out:
# Dataset Shape Before Removing Duplicates: (205, 10)
# Dataset Shape After Removing Duplicates: (200, 10)

# %%
print("\nColumns Before Removing Department Column:\n", df.columns)
df = df.drop("Department", axis=1)
print("\nColumns After Removing Department Column:\n", df.columns)
# Out:
# Columns Before Removing Department Column:
#  Index(['Student_ID', 'Gender', 'Study_Hours', 'Attendance_Percentage',
#        'Parent_Education', 'Internal_Assessment', 'Lab_Test_Score',
#        'External_POE_Score', 'ESE_Preparation', 'Department'],
#       dtype='object')
#
# Columns After Removing Department Column:
#  Index(['Student_ID', 'Gender', 'Study_Hours', 'Attendance_Percentage',
#        'Parent_Education', 'Internal_Assessment', 'Lab_Test_Score',
#        'External_POE_Score', 'ESE_Preparation'],
#       dtype='object')

# %%
le = LabelEncoder()
df["Gender"] = le.fit_transform(df["Gender"])
df["Parent_Education"] = le.fit_transform(df["Parent_Education"])
df["ESE_Preparation"] = le.fit_transform(df["ESE_Preparation"])
print("\nDataset After Encoding Categorical Variables:\n")
print(df.head())
# Out:
# Dataset After Encoding Categorical Variables:
#
#    Student_ID  Gender  Study_Hours  Attendance_Percentage  Parent_Education  \
# 0        1001       1          3.6                   68.0                 1
# 1        1002       1          7.7                   96.0                 2
# 2        1003       0          6.1                   55.0                 2
# 3        1004       1          5.2                   93.0                 1
# 4        1005       1          2.1                   52.0                 1
#
#    Internal_Assessment  Lab_Test_Score  External_POE_Score  ESE_Preparation
# 0                 17.0              16                  17                0
# 1                 22.0              18                  13                0
# 2                 10.0              20                  17                1
# 3                 25.0              21                  18                1
# 4                 16.0              19                  12                1

# %%
df["Average_Score"] = (df["Internal_Assessment"] +
 df["Lab_Test_Score"] +df["External_POE_Score"]) / 3
df["Result"] = df["Average_Score"].apply(lambda x: "Pass" if x >= 15 else "Fail")
print("\nDataset with Result Column:\n")
print(df[["Internal_Assessment","Lab_Test_Score","External_POE_Score","Average_Score","Result"]].head())
# Out:
# Dataset with Result Column:
#
#    Internal_Assessment  Lab_Test_Score  External_POE_Score  Average_Score  \
# 0                 17.0              16                  17      16.666667
# 1                 22.0              18                  13      17.666667
# 2                 10.0              20                  17      15.666667
# 3                 25.0              21                  18      21.333333
# 4                 16.0              19                  12      15.666667
#
#   Result
# 0   Pass
# 1   Pass
# 2   Pass
# 3   Pass
# 4   Pass

# %%
# Calculate Average Score
df["Average_Score"] = (
    df["Internal_Assessment"] +
    df["Lab_Test_Score"] +
    df["External_POE_Score"]
) / 3

# Assign Pass or Fail
df["Result"] = df["Average_Score"].apply(lambda x: "Pass" if x >= 15 else "Fail")

print("\nDataset with Result Column:\n")

print(df[[
    "Internal_Assessment",
    "Lab_Test_Score",
    "External_POE_Score",
    "Average_Score",
    "Result"
]].head())
# Out:
# Dataset with Result Column:
#
#    Internal_Assessment  Lab_Test_Score  External_POE_Score  Average_Score  \
# 0                 17.0              16                  17      16.666667
# 1                 22.0              18                  13      17.666667
# 2                 10.0              20                  17      15.666667
# 3                 25.0              21                  18      21.333333
# 4                 16.0              19                  12      15.666667
#
#   Result
# 0   Pass
# 1   Pass
# 2   Pass
# 3   Pass
# 4   Pass

# %%
df["Average_Score"] = (df["Internal_Assessment"] +
                       df["Lab_Test_Score"] +
                       df["External_POE_Score"]) / 3

df["Result"] = df["Average_Score"].apply(lambda x: "Pass" if x >= 15 else "Fail")

print("\nDataset with Result Column:\n")

print(df[["Internal_Assessment","Lab_Test_Score","External_POE_Score","Average_Score","Result"]].head())
# Out:
# Dataset with Result Column:
#
#    Internal_Assessment  Lab_Test_Score  External_POE_Score  Average_Score  \
# 0                 17.0              16                  17      16.666667
# 1                 22.0              18                  13      17.666667
# 2                 10.0              20                  17      15.666667
# 3                 25.0              21                  18      21.333333
# 4                 16.0              19                  12      15.666667
#
#   Result
# 0   Pass
# 1   Pass
# 2   Pass
# 3   Pass
# 4   Pass

# %%
scaler = StandardScaler()
features = ["Study_Hours",
 "Attendance_Percentage",
 "Internal_Assessment",]

# %%
scaler = StandardScaler()
features = ["Study_Hours",
 "Attendance_Percentage",
 "Internal_Assessment",
  "Lab_Test_Score",
 "External_POE_Score"]
print("\nValues Before Scaling:\n")
print(df[features].head())
df[features] = scaler.fit_transform(df[features])
print("\nValues After Scaling:\n")
print(df[features].head())
# Out:
# Values Before Scaling:
#
#    Study_Hours  Attendance_Percentage  Internal_Assessment  Lab_Test_Score  \
# 0          3.6                   68.0                 17.0              16
# 1          7.7                   96.0                 22.0              18
# 2          6.1                   55.0                 10.0              20
# 3          5.2                   93.0                 25.0              21
# 4          2.1                   52.0                 16.0              19
#
#    External_POE_Score
# 0                  17
# 1                  13
# 2                  17
# 3                  18
# 4                  12
#
# Values After Scaling:
#
#    Study_Hours  Attendance_Percentage  Internal_Assessment  Lab_Test_Score  \
# 0    -0.397086              -0.422315            -0.450391       -0.153456
# 1     1.614782               1.405428             0.425601        0.294590
# 2     0.829663              -1.270910            -1.676780        0.742636
# 3     0.388033               1.209599             0.951196        0.966659
# 4    -1.133135              -1.466739            -0.625590        0.518613
#
#    External_POE_Score
# 0           -0.024048
# 1           -0.940170
# 2           -0.024048
# 3            0.204982
# 4           -1.169201

# %%
X = df.drop(["Result","Average_Score"], axis=1)
y = df["Result"]
print("\nFeature Matrix Shape:", X.shape)
print("Target Vector Shape:", y.shape)
# Out:
# Feature Matrix Shape: (200, 9)
# Target Vector Shape: (200,)
